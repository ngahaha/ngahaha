# %%
import pandas as pd
import csv

df=pd.read_csv('Books.csv')
knn=df.pivot_table(values='Book-Rating',index='BookTitle',columns='UserID',fill_value=0)
knn.head(11)
# Out:
# UserID                                              0     1     ...  6290  6291
# BookTitle                                                       ...
# 007 El Mundo Nunca Es Suficiente                       0     0  ...     0     0
# 4000 Vornamen aus aller Welt. Von Alexander bis...     0     0  ...     0     0
# A Kid's Guide to How to Save the Planet (Camelo...     0     0  ...     0     0
# A Kiss of Shadows (Meredith Gentry Novels (Pape...     0     0  ...     0     0
# A Painted House                                        0     0  ...     0     0
# A String in the Harp                                   0     0  ...     0     0
# A Wrinkle In Time                                      0     0  ...     0     0
# Adressat unbekannt.                                    0     0  ...     0     0
# Advanced Photography, Sixth Edition                    0     0  ...     0     0
# Alaska                                                 0     0  ...     0     0
# Alice's Adventures in Wonderland and Through th...     0     0  ...     0     0
#
# [11 rows x 6292 columns]

# %%
# create mapper from movie title to index
# movie: index
movie_to_idx = {
    movie: i for i, movie in enumerate(list(df.set_index('UserID').iloc[knn.index].BookTitle))
}
movie_to_idx
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-5e5f10c1da1a> in <module>()
#       1 movie_to_idx = {
# ----> 2     movie: i for i, movie in enumerate(list(df.set_index('UserID').iloc[knn.index].BookTitle))
#       3 }
#       4 movie_to_idx
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2127         # a list of integers
#    2128         elif is_list_like_indexer(key):
# -> 2129             return self._get_list_axis(key, axis=axis)
#    2130
#    2131         # a single integer
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _get_list_axis(self, key, axis)
#    2109         """
#    2110         try:
# -> 2111             return self.obj._take_with_is_copy(key, axis=axis)
#    2112         except IndexError:
#    2113             # re-raise with different error message
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in _take_with_is_copy(self, indices, axis, **kwargs)
#    3407         See the docstring of `take` for full explanation of the parameters.
#    3408         """
# -> 3409         result = self.take(indices=indices, axis=axis, **kwargs)
#    3410         # Maybe set copy if we didn't actually change the index.
#    3411         if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3393
#    3394         new_data = self._data.take(
# -> 3395             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3396         )
#    3397         return self._constructor(new_data).__finalize__(self)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in take(self, indexer, axis, verify, convert)
#    1379             np.arange(indexer.start, indexer.stop, indexer.step, dtype="int64")
#    1380             if isinstance(indexer, slice)
# -> 1381             else np.asanyarray(indexer, dtype="int64")
#    1382         )
#    1383
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py in asanyarray(a, dtype, order)
#     136
#     137     """
# --> 138     return array(a, dtype, copy=False, order=order, subok=True)
#     139
#     140
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in __array__(self, dtype)
#     623         The array interface, return my values.
#     624         """
# --> 625         return np.asarray(self._data, dtype=dtype)
#     626
#     627     def __array_wrap__(self, result, context=None):
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: invalid literal for int() with base 10: '007 El Mundo Nunca Es Suficiente'

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
# set up orthographic map projection with
# perspective of satellite looking down at 50N, 100W.
# use low resolution coastlines.
map = Basemap(projection='ortho',lat_0=45,lon_0=-100,resolution='l')
# draw coastlines, country boundaries, fill continents.
map.drawcoastlines(linewidth=0.25)
map.drawcountries(linewidth=0.25)
map.fillcontinents(color='coral',lake_color='aqua')
# draw the edge of the map projection region (the projection limb)
map.drawmapboundary(fill_color='aqua')
# draw lat/lon grid lines every 30 degrees.
map.drawmeridians(np.arange(0,360,30))
map.drawparallels(np.arange(-90,90,30))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-0e67c46a56a3> in <module>()
# ----> 1 from mpl_toolkits.basemap import Basemap
#       2 import matplotlib.pyplot as plt
#       3 import numpy as np
#       4 # set up orthographic map projection with
#       5 # perspective of satellite looking down at 50N, 100W.
#
# ModuleNotFoundError: No module named 'mpl_toolkits.basemap'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
